# %%
import pandas as pd

# %%
df = pd.DataFrame({'A': [1,2,3,1], 'B': [2,1,3,3], 'C': [3,2,1,4]})
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  2  1  2
# 2  3  3  1
# 3  1  3  4

# %%
out_df = pd.DataFrame({'A': [1], 'B': [2], 'C': [3]})
out_df
# Out:
#    A  B  C
# 0  1  2  3

# %%
condition_dict_1 = {'A': 1, 'B': 2, 'C': 3}
keys = condition_dict_1.keys()
col_list = list(keys)
col_list[0]
# Out:
# 'A'

# %%
condition_dict_1['A']
# Out:
# 1

# %%
print(f'col_{1}')
# Out:
# col_1

# %%
len(col_list)
# Out:
# 3

# %%
keys = condition_dict_1.keys()
col_list = list(keys)
# Out:
# A 1
# B 2
# C 3

# %%
for i,j in condition_dict_1.items():
    print(i,j)
# Out:
# A 1
# B 2
# C 3

# %%
from functools import reduce

mask = reduce(lambda a, b: a & b, [df[col] == val for col, val in condition_dict_1.items()])
df[mask]
# print(mask)
# Out:
#    A  B  C
# 0  1  2  3

# %%
keys = condition_dict_1.keys()
col_list = list(keys)

condition = ""
for i in range(0, len(col_list)): 
    col_name = "col" + str(i)
    val_name = "val" + str(i)
    col_name = col_list[i]

    val_name = condition_dict_1[col_name]

    
    # print(cond)

    if i == len(col_list)-1:
        cond = "(df['" + str(col_name)+ "']==" + str(val_name) + ")"
        condition  += str(cond)

    else:
        cond = "(df['" + str(col_name)+ "']==" + str(val_name) + ")&"
        condition += str(cond)

    # return df[condition]


    # print(col_name ,val_name )
# print(condition)

df[eval(condition)]
# Out:
#    A  B  C
# 0  1  2  3

# %%
df[(df['col1']== 1) & (df['col2']== 1)]

# %%
#Question
#Dictionary of Conditions
condition_dict_1 = {'A': 1, 'B': 2, 'C': 3}
#Input DataFrame
df = pd.DataFrame({'A': [1,2,3,1], 'B': [2,1,3,3], 'C': [3,2,1,4]})
#Filter out all rows from input dataframe which satisfy all conditions in the dict. 
# In this case, the conditions are all rows where column A has value 1, column B has value 2 and column C has value 3.

 
def filter_df(df, dict1):
    keys = condition_dict_1.keys()
    col_list = list(keys)

    condition = "["
    for i in range(0, len(col_list)): 
        col_name = "col" + str(i)
        val_name = "val" + str(i)
        col_name = col_list[i]

        val_name = condition_dict_1[col_name]

        
        # print(cond)

        if i == len(col_list)-1:
            cond = "(df['" + str(col_name)+ "']==" + str(val_name) + ")]"
            condition  += str(cond)

        else:
            cond = "(df['" + str(col_name)+ "']==" + str(val_name) + ")&"
            condition += str(cond)

        # return df[condition]


        # print(col_name ,val_name )
    # print(condition)

    df[condition]
 

    # return df_output
 
df = pd.DataFrame({'A': [1,2,3,1], 'B': [2,1,3,3], 'C': [3,2,1,4]})
conditions = {'A': 1, 'B': 2, 'C': 3}
output = filter_df(df, conditions )
 
# Output:
out_df = pd.DataFrame({'A': [1], 'B': [2], 'C': [3]})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: "[(df['A']==1)&(df['B']==2)&(df['C']==3)]"
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
