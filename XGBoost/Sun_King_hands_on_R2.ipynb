# %%
l = [8,4,6,1,10,5]

# %%
d = dict()

# %%
for i in l:
    d[i] = i**2

# %%
d
# Out:
# {8: 64, 4: 16, 6: 36, 1: 1, 10: 100, 5: 25}

# %%
dt = {1:22,10:9,8:34,12:18, 4:16, 5:1,0:36}

# %%
dt[1]
# Out:
# 22

# %%
dt.values()
# Out:
# dict_values([22, 9, 34, 18, 16, 1, 36])

# %%
v = sorted(dt.values())
v
# Out:
# [1, 9, 16, 18, 22, 34, 36]

# %%
k = dict()
for i in v:
    for key, value in dt.items():
        if i == value:
            k[key]  = value

# %%
k
# Out:
# {5: 1, 10: 9, 4: 16, 12: 18, 1: 22, 8: 34, 0: 36}

# %%
#sum of squares of first n natural numbers

# %%
def sum_sqr(n):
    sum_sq = n*(n+1)*(2*n+1)/6
    return sum_sq

# %%
sum_sqr(3)
# Out:
# 14.0

# %%
s = '%<ksatsihtgnitelp>$mo#(cnosnoital)&utar~’gnoC’.!'
type(s)
# Out:
# str

# %%
l = [ "%", "<", ">", "$", "#", "(", ")", "&" ]
for i in l:
    n = s.replace(i," ")
n
# Out:
# '%<ksatsihtgnitelp>$mo#(cnosnoital) utar~’gnoC’.!'

# %%
s1 = s[0]
s1
# Out:
# '%'

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/sheetalsuwalka/Documents/Project/XGBoost'

# %%
import pandas as pd

# %%
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.select_dtypes(include = ['object'])
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
df._get_numeric_data().columns
# Out:
# Index(['age', 'bmi', 'children', 'charges'], dtype='object')

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import matplotlib.pyplot as plt

# %%
df['age'].plot(kind = 'hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
df.plot(df['age'], df['charges'], kind = 'scatter')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [76], in <cell line: 1>()
# ----> 1 plt(df['age'], df['charges'], kind = 'scatter')
#
# TypeError: 'module' object is not callable

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df['charges'].plot(kind = 'hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.plot(kind = 'hist', subplots = True, figsize = (8,8))
# Out:
# array([<AxesSubplot: ylabel='Frequency'>,
#        <AxesSubplot: ylabel='Frequency'>,
#        <AxesSubplot: ylabel='Frequency'>,
#        <AxesSubplot: ylabel='Frequency'>], dtype=object)

# %%
df['charges'].plot(kind = 'box')
# Out:
# <AxesSubplot: >

# %%
df.boxplot()
# Out:
# <AxesSubplot: >

# %%
df.plot.scatter('age','charges')
# Out:
# <AxesSubplot: xlabel='age', ylabel='charges'>

# %%
df.plot('age', 'charges', kind = 'scatter', subplots=True, xlabel = 'AGE', xlim = (20,50), figsize = (10,5), 
        title = 'Scatter_plot_age_vs_charges')
# Out:
# array([<AxesSubplot: xlabel='AGE', ylabel='charges'>], dtype=object)
