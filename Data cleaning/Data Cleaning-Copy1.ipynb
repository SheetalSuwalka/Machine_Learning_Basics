# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
df1 = pd.read_excel("HR Dataset.xlsx")

# %%
df1.head()
# Out:
#    Serial No  Age Qualification  Experience   Domain       Skill Designation  \
# 0          1   25           MCA           3     BFSI        Java          SE
# 1          2   26           MSc           4     BFSI      Oracle          SE
# 2          3   24            BE           2     BFSI        Java          SE
# 3          4   31           MCA           9  Telecom         C++        Lead
# 4          5   30         Mtech           7  Telecom  Networking        Lead
#
#           Project   Salary  Rating   ESS Status
# 0        Citi Bank     4.0       5  4.10   Left
# 1        Citi Bank     4.0       4  3.15   Left
# 2  Bank of America     2.5       4  3.30   Left
# 3         Erickson    10.0       4  3.03   Left
# 4         Erickson    10.0       5  3.40   Left

# %%
df2 = pd.get_dummies(df1['Status'])

# %%
df1.drop('Status',axis = 1)
# Out:
#     Serial No  Age Qualification  Experience         Domain       Skill  \
# 0           1   25           MCA           3           BFSI        Java
# 1           2   26           MSc           4           BFSI      Oracle
# 2           3   24            BE           2           BFSI        Java
# 3           4   31           MCA           9        Telecom         C++
# 4           5   30         Mtech           7        Telecom  Networking
# 5           6   27            BE           5           BFSI        Java
# 6           7   30      Graduate           8           BFSI   Mainframe
# 7           8   31      Graduate           8        Telecom         C++
# 8           9   27         Mtech           2        Telecom  Networking
# 9          10   24           MCA           2           BFSI        Java
# 10         11   29            CA           5  Manufacturing      SAP(F)
# 11         12   31           MCA           8  Manufacturing      SAP(T)
# 12         13   33           MCA          10           BFSI        Java
# 13         14   25           MCA           3           BFSI        Java
# 14         15   26           MSc           4           BFSI      Oracle
# 15         16   24            BE           2           BFSI        Java
# 16         17   31           MCA           9        Telecom         C++
# 17         18   30           MCA           7        Telecom  Networking
# 18         19   27            BE           5           BFSI        Java
# 19         20   30      Graduate           8           BFSI   Mainframe
# 20         21   31      Graduate           8        Telecom         C++
# 21         22   27         Mtech           2        Telecom  Networking
# 22         23   24           MCA           2           BFSI        Java
# 23         24   29            CA           5  Manufacturing      SAP(F)
# 24         25   31           MCA           8  Manufacturing      SAP(T)
# 25         26   35           BSc          14           BFSI        Java
# 26         27   29           MSc           7           BFSI      Oracle
# 27         28   24            BE           2           BFSI        Java
# 28         29   31           BSc           9        Telecom         C++
# 29         30   30            BE           8        Telecom  Networking
# 30         31   27            BE           5           BFSI        Java
# 31         32   30      Graduate           8           BFSI   Mainframe
# 32         33   31      Graduate           8        Telecom         C++
# 33         34   27         Mtech           2        Telecom  Networking
# 34         35   24           MSc           2           BFSI        Java
# 35         36   29           MBA           5  Manufacturing      SAP(F)
# 36         37   31            BE           8  Manufacturing      SAP(T)
# 37         38   33            BE          10           BFSI        Java
# 38         39   30           MCA           8           BFSI        Java
# 39         40   26           MSc           4           BFSI      Oracle
# 40         41   24            BE           2           BFSI        Java
# 41         42   31           MCA           9        Telecom         C++
# 42         43   30           MCA           9        Telecom  Networking
# 43         44   27            BE           5           BFSI        Java
# 44         45   35      Graduate          13           BFSI   Mainframe
# 45         46   31      Graduate           8        Telecom         C++
# 46         47   28         Mtech           3        Telecom  Networking
# 47         48   24           MSc           2           BFSI        Java
# 48         49   39          Mcom          15  Manufacturing      SAP(F)
# 49         50   31           MBA           8  Manufacturing      SAP(T)
#
#    Designation         Project   Salary  Rating   ESS  Left  Not Left
# 0           SE        Citi Bank     4.0       5  4.10     1         0
# 1           SE        Citi Bank     4.0       4  3.15     1         0
# 2           SE  Bank of America     2.5       4  3.30     1         0
# 3         Lead         Erickson    10.0       4  3.03     1         0
# 4         Lead         Erickson    10.0       5  3.40     1         0
# 5          SSE  Bank of America     4.0       3  2.90     1         0
# 6          SSE     Wells Farago     6.0       3  3.00     1         0
# 7          SSE         Erickson     6.0       3  3.10     1         0
# 8           SE         Erickson     4.0       5  3.20     1         0
# 9           SE        Citi Bank     3.0       4  3.30     1         0
# 10         SSE        Coca Cola     8.0       4  3.10     1         0
# 11         SSE            Apple     8.0       3  3.00     1         0
# 12        Lead        Citi Bank    12.0       2  3.40     1         0
# 13          SE        Citi Bank     4.0       5  4.10     1         0
# 14          SE        Citi Bank     4.0       4  3.15     1         0
# 15          SE  Bank of America     2.5       4  3.30     1         0
# 16        Lead         Erickson    10.0       4  3.03     1         0
# 17        Lead         Erickson    10.0       5  3.40     1         0
# 18         SSE  Bank of America     4.0       3  2.90     1         0
# 19         SSE     Wells Farago     6.0       3  3.00     1         0
# 20         SSE         Erickson     6.0       3  3.10     1         0
# 21          SE         Erickson     4.0       5  3.20     1         0
# 22          SE        Citi Bank     3.0       4  3.30     1         0
# 23         SSE        Coca Cola     8.0       4  3.10     1         0
# 24         SSE        Coca Cola     8.0       3  3.00     1         0
# 25         SSE        Citi Bank    11.0       3  4.20     0         1
# 26        Lead        Citi Bank    11.0       4  3.50     0         1
# 27          SE  Bank of America     2.5       4  3.40     0         1
# 28        Lead         Erickson    10.0       4  3.60     0         1
# 29        Lead         Erickson     9.0       3  3.40     0         1
# 30         SSE  Bank of America     4.0       3  3.10     0         1
# 31         SSE     Wells Farago     6.0       3  3.20     0         1
# 32         SSE         Erickson     6.0       3  3.15     0         1
# 33          SE         Erickson     4.0       5  3.45     0         1
# 34          SE        Citi Bank     3.0       4  3.30     0         1
# 35         SSE            Apple     8.0       4  3.10     0         1
# 36         SSE            Apple     8.0       3  3.00     0         1
# 37        Lead        Citi Bank    13.0       2  3.40     0         1
# 38        Lead        Citi Bank    11.0       4  4.10     0         1
# 39          SE        Citi Bank     4.0       4  3.15     0         1
# 40          SE  Bank of America     2.5       4  3.30     0         1
# 41        Lead         Erickson    10.0       4  3.05     0         1
# 42        Lead         Erickson    10.0       4  3.40     0         1
# 43         SSE  Bank of America     4.0       3  3.15     0         1
# 44         SSE     Wells Farago    10.0       3  3.30     0         1
# 45         SSE         Erickson     6.0       3  3.10     0         1
# 46          SE         Erickson     4.0       3  3.20     0         1
# 47          SE        Citi Bank     3.5       4  3.30     0         1
# 48        Lead        Coca Cola    15.0       3  3.40     0         1
# 49         SSE        Coca Cola    11.0       3  3.30     0         1

# %%
df1 = df1.join(df2)

# %%
corr = df1.corr()

# %%
corr
# Out:
#             Serial No       Age  Experience    Salary    Rating       ESS  \
# Serial No    1.000000  0.247025    0.226894  0.225267 -0.278286  0.037205
# Age          0.247025  1.000000    0.956044  0.869285 -0.509858  0.003936
# Experience   0.226894  0.956044    1.000000  0.857237 -0.551027  0.068844
# Salary       0.225267  0.869285    0.857237  1.000000 -0.298450  0.183772
# Rating      -0.278286 -0.509858   -0.551027 -0.298450  1.000000  0.314379
# ESS          0.037205  0.003936    0.068844  0.183772  0.314379  1.000000
# Left        -0.866199 -0.205777   -0.229986 -0.217435  0.235460 -0.202567
# Not Left     0.866199  0.205777    0.229986  0.217435 -0.235460  0.202567
#
#                 Left  Not Left
# Serial No  -0.866199  0.866199
# Age        -0.205777  0.205777
# Experience -0.229986  0.229986
# Salary     -0.217435  0.217435
# Rating      0.235460 -0.235460
# ESS        -0.202567  0.202567
# Left        1.000000 -1.000000
# Not Left   -1.000000  1.000000
