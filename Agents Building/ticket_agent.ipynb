# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/sheetalsuwalka/Documents/Personal Projects/Agents Building

# %%
from flight_booking_agent import FlightTicketBookingAgent

agent = FlightTicketBookingAgent()
agent.handle_request("Find a flight from New York to London for 2 passengers")

# %%
agent.handle_request("Book the cheapest flight from New York to London for Sarah", passenger_name="Sarah")
